# %%
# !pip install ucimlrepo

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
heart_disease = fetch_ucirepo(id=45)

# data (as pandas dataframes)
X = heart_disease.data.features
y = heart_disease.data.targets

# metadata
print(heart_disease.metadata)

# variable information
print(heart_disease.variables)
# Out:
# {'uci_id': 45, 'name': 'Heart Disease', 'repository_url': 'https://archive.ics.uci.edu/dataset/45/heart+disease', 'data_url': 'https://archive.ics.uci.edu/static/public/45/data.csv', 'abstract': '4 databases: Cleveland, Hungary, Switzerland, and the VA Long Beach', 'area': 'Health and Medicine', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 303, 'num_features': 13, 'feature_types': ['Categorical', 'Integer', 'Real'], 'demographics': ['Age', 'Sex'], 'target_col': ['num'], 'index_col': None, 'has_missing_values': 'yes', 'missing_values_symbol': 'NaN', 'year_of_dataset_creation': 1989, 'last_updated': 'Fri Nov 03 2023', 'dataset_doi': '10.24432/C52P4X', 'creators': ['Andras Janosi', 'William Steinbrunn', 'Matthias Pfisterer', 'Robert Detrano'], 'intro_paper': {'ID': 231, 'type': 'NATIVE', 'title': 'International application of a new probability algorithm for the diagnosis of coronary artery disease.', 'authors': 'R. Detrano, A. Jánosi, W. Steinbrunn,
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the aesthetic style of the plots
sns.set_style("whitegrid")

# Create a figure with subplots
plt.figure(figsize=(15, 5))

# Plot 1: Distribution of the target variable 'num'
plt.subplot(1, 3, 1) # 1 row, 3 columns, 1st plot
sns.countplot(x=y['num'], hue=y['num'], palette='viridis', legend=False)
plt.title('Distribution of Heart Disease Diagnosis (num)')
plt.xlabel('Diagnosis (0 = No Disease, 1-4 = Disease)')
plt.ylabel('Count')

# Plot 2: Distribution of 'age'
plt.subplot(1, 3, 2) # 1 row, 3 columns, 2nd plot
sns.histplot(X['age'], bins=10, kde=True, color='skyblue')
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Count')

# Plot 3: Distribution of 'sex'
plt.subplot(1, 3, 3) # 1 row, 3 columns, 3rd plot
sns.countplot(x=X['sex'], hue=X['sex'], palette='mako', legend=False)
plt.title('Distribution of Sex')
plt.xlabel('Sex (1 = Male, 0 = Female)')
plt.ylabel('Count')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-883994238.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=y['num'], palette='viridis')
# /tmp/ipython-input-883994238.py:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=X['sex'], palette='mako')

# %% [markdown]
# Nous pouvons également visualiser la relation entre le sexe et le diagnostic de maladie cardiaque.

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x=X['sex'], hue=y['num'], palette='rocket')
plt.title('Heart Disease Diagnosis by Sex')
plt.xlabel('Sex (1 = Male, 0 = Female)')
plt.ylabel('Count')
plt.legend(title='Diagnosis', labels=['No Disease (0)', 'Disease (1)', 'Disease (2)', 'Disease (3)', 'Disease (4)'])
plt.show()
